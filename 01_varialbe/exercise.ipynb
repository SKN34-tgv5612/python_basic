# %%
# 변수 생성
# 변수명 = 자료

name = "호일동"
age = 20

# 변수 출력
print(name)
print(age)
# Out:
# 호일동
# 20

# %%
score = 10
print(score)   # 10

score = 20
print(score)   # 20
# Out:
# 10
# 20

# %%
x = 10
y = x + 5

print(y)   # 15
# Out:
# 15

# %%
# 좌항은 변수명, 우항은 원시 문자열로 표현된 자료
team_name = "ohgiraffers"

# 좌항은 변수명, 우항은 team_name 변수에 담긴 값 "ohgiraffers"
my_team = team_name

# %%
# 키(cm) 정보를 변수에 담아보세요
height = 207.3

a = 171.8    # 변수명만 보고는 키인지, 몸무게인지, BMI인지, 시력인지... 알 수 없음

# %%
team_name= "오지라퍼스"
print(team_name)   # 오지라퍼스

team_name= "오지라퍼스"
print(team_name)   # 오지라퍼스
# print(Team_name)   # 오지라퍼스
# Out:
# 오지라퍼스
# 오지라퍼스

# %%
우리팀 = "ArithmeticError"

# %%
# 좋은 변수명 예시
# user_name, total_price, is_active

# 나쁜 변수명 (의미 불명)
# a, b, temp

# %%
team_@_name = "오지라퍼스"    # SyntaxError 발생
# Out:
#   Cell In[20], line 1
#     team_@_name = "오지라퍼스"    # SyntaxError 발생
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
else = "오지라퍼스"    # 컴파일 오류 발생
# Out:
#   Cell In[21], line 1
#     else = "오지라퍼스"    # 컴파일 오류 발생
#     ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# 파이썬에서 언더스코어의 사용은 다음 네가지와 같은 특별한 기능을 제공한다.
# 1. 변수명 구분용 (snake_case)
# 2. 무시하고 싶은 변수명으로 사용

# %%
10
# Out:
# 10

# %%
print(_)
# Out:
# 10

# %%
print(_ *3)
# Out:
# 30

# %%
print(_)
# Out:
# 10

# %%
# 특정 값을 무시
x, _, z = (1,2,3)
print(x)    # 1
print(z)    # 3

# 앞에 *을 추가로 붙여 여러 개의 값 무시
x, *_, y = (1, 2, 3, 4, 5)
print(x)    # 1
print(y)    # 5

# %%
for _ in range(5):
    print("Hello, World!")
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!

# %%
_internal_name = 'one_module'  # private 변수처럼 선언
_internal_version = '1.0'      # private 변수처럼 선언

# %%
million = 1_000_000
print(million)   # 1000000
# Out:
# 1000000

# %%
# _ -> 내부용 또는 값 무시
# __ -> private 변수처럼 사용 (클래스 내부에서만 접근 가능)
# __name__ -> 파이썬에서 특별한 의미를 가지는 변수 (모듈 이름을 담고 있음)
