# %%
from team_management import developers, managers

print(managers.get_managers())
print(developers.get_developers())
# Out:
# 팀장 : 카피바라
# 개발자 : 산골 카피바라

# %%
from work_management import task_tracking , reporting

print(task_tracking.start_task("파이썬 공부"))
print(task_tracking.end_task("파이썬 공부"))
print(reporting.generate_report("파이썬 공부"))
# Out:
# 작업 '파이썬 공부' 시작됨.
# 작업 '파이썬 공부 종료됨.
# '파이썬 공부' 작업 보고서 생성됨.

# %%
from schedule_management.calendar import add_event, remove_event
from datetime import datetime
print(add_event("회의", datetime.now().strftime("%Y-%m-%d")))
print(remove_event("회의"))
# Out:
# 2026-06-22 에 '회의'일정이 추가되었습니다.
# 회의 일정이 삭제되었습니다.

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip freeze > requirements.txt
# %pip list --format=freeze > requirements.txt # 아나콘다 환경에서 강제 버전 설정
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %/opt/miniconda3/envs/pystudy/bin/python -m venv new_env
# %source new_env/bin/activate
# %pip install -r requirements.txt
